# %% [markdown]
# # Grupo 5 -   Embedding Layer + RNN/LSTM/GRU

# %% [markdown]
# ## Sumário
#
# - **1. Setup**
#
# - **2. Carregamento e Preparação dos Dados**
#   - **2.1 Carregamento dos dados**
#   - **2.2 Preparação dos dados**
#   - **2.3 Divisão dos dados**
#   - **2.4 Tokenização**
#   - **2.5 Normalização**
#   - **2.6 Categorizar Labels**
#
# - **3. Rede Neural Classificação**
#   - **3.1 Definição da rede neural**
#   - **3.2 Treinamento da rede neural**
#
# - **4. Resultados**
#   - **4.1 Avaliação do modelo**
#     - **4.1.1 RNN**
#       - **4.1.1.1 Acompanhamento por época**
#       - **4.1.1.2 Comparação Métricas**
#       - **4.1.1.3 Matriz de confusão**
#   - **4.2 Avaliação do modelo**
#     - **4.1.2 LSTM**
#       - **4.1.2.1 Acompanhamento por época**
#       - **4.1.2.2 Comparação Métricas**
#       - **4.1.2.3 Matriz de confusão**
#   - **4.3 Avaliação do modelo**
#     - **4.1.3 GRU**
#       - **4.1.3.1 Acompanhamento por época**
#       - **4.1.3.2 Comparação Métricas**
#       - **4.1.3.3 Matriz de confusão**
#
# - **5. Performance**
#   - **5.1 CPU**
#   - **5.2 GPU**
#
# - **6. Predições**
#   - **6.1 RNN**
#   - **6.2 LSTM**
#   - **6.3 GRU**

# %% [markdown]
# # 1. Setup
#
# Seção para realizar a prepração do ambiente de desenvolvimento, realizando a conexão com o Google Drive e importando as bibliotecas necessárias.

# %%
# Montagem do drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Importar bibliotecas
import time
import psutil
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import confusion_matrix

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, SimpleRNN, GRU, Dense, Dropout, Bidirectional, GlobalMaxPooling1D, LSTM
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import RMSprop, Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# %% [markdown]
# # 2. Carregamento e Preparação dos Dados
#
# Nesta seção é feito o carregamento da base de dados que está salva no drive compartilhado da turma, e fazendo todo o pré processamento dos dados, como separar em treino e teste, tokenizar, normalizar os paddings para utilizar no modelo com Embedding e transformando para número as intenções.

# %% [markdown]
# ## 2.1 Carregamento dos Dados

# %%
# Carregar os dados
PATH = '/content/drive/Shareddrives/Grupo_05/baseTratada_v3_20240909.xlsx'
data = pd.read_excel(PATH)

# %%
# Exibir as primeiras linhas do dataset
data = data[['Intencao', 'Pergunta_Lematizada', 'Resposta_Lematizada']]
data.head()
# Out:
#                                Intencao  \
# 0                       Como depositar
# 1                    Como fazer remessa
# 2                      Tempo de remessa
# 3  Pedido de envio via metodo "ByPhone"
# 4  Pedido de envio via metodo "ByPhone"
#
#                                  Pergunta_Lematizada  \
# 0  dia gostar caixa family mart verde eh hora tra...
# 1                               enviar dinheiro japo
# 2                 levar beneficirio receber dinheiro
# 3                     acabar transferncia total iene
# 4  poder remesso iene     iene      caixa econmic...
#
#                                  Resposta_Lematizada
# 0  dia senhor utilizar carto depsito mquino hora ...
# 1  inscrever servio remessar baixe aplicativo bra...
# 2  via regro remessa sero pago ver pix hora dado ...
# 3                     ir processar solicitacao otimo
# 4                     ir processar solicitacao otimo

# %% [markdown]
# ## 2.2 Preparação dos dados

# %%
# Junção das colunas de perguntas e resposta para treinamento do modelo
perguntas = data[['Intencao', 'Pergunta_Lematizada']].copy()
respostas = data[['Intencao', 'Resposta_Lematizada']].copy()
perguntas = perguntas.rename(columns={'Pergunta_Lematizada': 'Texto'})
respostas = respostas.rename(columns={'Resposta_Lematizada': 'Texto'})
base = pd.concat([perguntas,respostas])
base.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1564 entries, 0 to 781
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Intencao  1564 non-null   object
#  1   Texto     1553 non-null   object
# dtypes: object(2)
# memory usage: 36.7+ KB

# %%
# Retirando valores nulos e duplicados
base = base.dropna()
base = base.drop_duplicates(subset='Texto')
base.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1156 entries, 0 to 781
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Intencao  1156 non-null   object
#  1   Texto     1156 non-null   object
# dtypes: object(2)
# memory usage: 27.1+ KB

# %%
# Retirando intenções que possuem menos de 10 colunas
base[base['Intencao'] != 'Envio via Deposit Code']
base[base['Intencao'] != 'Regras do servico']
base[base['Intencao'] != 'Dificuldades com utilizacao do App']
# Out:
#                                  Intencao  \
# 0                         Como depositar
# 1                      Como fazer remessa
# 2                        Tempo de remessa
# 3    Pedido de envio via metodo "ByPhone"
# 4    Pedido de envio via metodo "ByPhone"
# ..                                    ...
# 775     Solicitacao de cartao de remessas
# 776                        Acesso a conta
# 777                     Como se inscrever
# 780      Problemas/Duvidas sobre remessas
# 781  Pedido de envio via metodo "ByPhone"
#
#                                                  Texto
# 0    dia gostar caixa family mart verde eh hora tra...
# 1                                 enviar dinheiro japo
# 2                   levar beneficirio receber dinheiro
# 3                       acabar transferncia total iene
# 4    poder remesso iene     iene      caixa econmic...
# ..                                                 ...
# 775  diaa poder solicitar carto laranja aplicativo ...
# 776  dia voc esquecer senhar acesso aplicativo voc ...
# 777  inscrever basta download aplicativo inserir da...
# 780  caso dar bancrio beneficirio    corrigir prxim...
# 781  dia j consta aplicativo caso desejar depositar...
#
# [1154 rows x 2 columns]

# %% [markdown]
# ## 2.3 Divisão dos dados

# %%
# Definição de labels e dados que serão utilizados para o treinamento
quests = base['Texto'].astype(str).values
labels = base['Intencao'].values

# %%
# Dividir os dados em conjuntos de treinamento e teste sendo 80% e 20%
train_data, test_data, train_labels, test_labels = train_test_split(quests, labels, test_size=0.20, random_state=42)

# %% [markdown]
# ## 2.4 Tokenização

# %%
# Tokenização das perguntas com um token OOV para palavras desconhecidas
tokenizer = Tokenizer(oov_token="<OOV>")
tokenizer.fit_on_texts(train_data)  # Tokeniza o texto
train_sequences = tokenizer.texts_to_sequences(train_data)
test_sequences = tokenizer.texts_to_sequences(test_data)

# %%
# Visualizando as sequências geradas
print("Sequências de treino:", train_sequences)
print("Sequências de teste:", test_sequences)
# Out:
# Sequências de treino: [[4, 26, 704, 31, 6], [172, 4, 19, 24, 527, 6, 83, 33, 160], [42, 2, 22, 84, 19, 101, 6], [2, 84, 264, 17, 84, 194, 17, 21, 4, 7, 8, 84, 288, 81, 74, 81, 31, 9, 81, 265, 16, 7, 368, 17, 21, 705, 151, 3], [48, 22, 36, 50, 19, 13, 6], [2, 161, 141, 439, 216, 7, 28, 97, 7, 266, 29, 102, 195, 7, 125, 2, 7, 125, 65, 20, 4, 706, 58, 7, 102, 65, 130, 369, 60], [120, 2, 4, 80, 24, 36, 5, 24, 6], [2, 95, 62, 110, 7, 31, 27, 39, 246, 324, 440, 707, 7], [289, 36, 83, 181, 95, 31, 44, 142, 708, 121], [2, 18, 50, 131, 43, 32], [48, 4, 19, 13, 247], [217, 441, 2, 370, 528, 442, 41, 47, 182, 66], [173, 2, 709, 5, 41, 174, 162, 31, 160], [2, 76, 710, 13, 20, 175, 711, 54], [2, 21, 143, 25, 25, 101, 267, 45], [2, 27, 53, 80, 98], [2, 9, 5, 111, 23, 10, 11], [25, 25, 33, 205, 3, 55, 72, 16, 7, 8, 38, 112, 529, 325, 326, 218], [327, 290, 2, 14, 248, 73, 80, 37, 15, 10, 183], [2, 73, 712, 713, 268, 4, 714, 5, 715, 716, 717, 58, 268, 74, 249, 49, 28, 718, 371, 530, 141, 21, 33, 132, 328, 5, 443, 63, 719, 531, 532, 720, 444, 531, 721, 174, 328, 5, 532, 722, 328, 723, 5, 21, 291, 115, 85, 724, 445, 219, 725, 329, 726, 329, 5, 727, 21, 115, 85, 728, 21, 372, 729, 6], [730, 731, 732, 446, 98, 733, 734, 184], [2, 175, 735, 736], [163, 144, 2, 31, 7], [447, 185, 737, 88, 86, 292, 93, 448], [163, 122, 5, 113, 293, 36, 145], [146, 147, 19, 89, 12, 6], [50, 24, 12, 6], [48, 126, 3, 55, 293, 738, 40, 13, 12, 55, 72, 16, 40, 37, 325, 218, 326, 739, 112, 25, 293, 152, 740, 98, 123, 123, 373, 269], [2, 164, 16, 51, 16, 18, 61, 92, 10, 11], [22, 4, 7, 14], [2, 220, 741, 221, 14, 248, 182, 138, 742, 222, 247, 22, 196, 5, 24, 223, 374, 221], [533, 4, 53, 186, 270], [534, 250, 535, 743, 77, 10, 251, 76, 36, 375, 6, 24, 4, 19, 93], [103, 26, 87, 9, 5, 17, 68], [130, 536, 85, 104, 56, 537, 36, 184], [22, 376, 377, 87, 15, 187, 13, 30, 330, 294], [42, 18, 4, 39, 295, 73, 133, 57, 39, 49, 104], [68, 9, 153, 206, 449, 207, 331], [2, 19, 33, 71, 744, 89, 12], [2, 36, 46, 23, 10, 11, 745], [2, 4, 19, 3, 746, 747, 81, 7, 8, 4, 7, 30, 45, 114, 52, 3, 8, 38, 81, 208, 72, 81, 55, 748, 81, 378, 176, 296, 52, 99, 3, 266, 4, 96, 165, 166, 154, 3, 8, 113, 224, 113, 176, 296, 142, 34, 15, 379, 538, 4, 19, 96, 4, 19, 34, 15, 142, 332, 132, 252, 266, 4, 188, 332, 142, 32, 209, 51, 188, 539, 328, 450, 297, 14, 540, 298, 541], [22, 146, 749, 147, 19, 89, 12, 750, 5], [2, 27, 14, 451, 26, 71, 331, 15, 51, 22, 297, 751], [50, 44, 54, 271, 333], [48, 148, 14, 17, 22, 50, 197, 9, 452, 50, 272], [48, 126, 3, 78, 380, 453, 55, 72, 16], [253, 15, 51, 19], [209], [84, 264, 17, 84, 194, 17, 56, 454, 334, 455, 542, 752, 186, 268, 4, 225, 335, 29, 85, 456, 63, 79, 336, 114, 127, 98], [120, 175, 17, 15], [35, 12, 3, 8, 33, 52], [381, 17], [39, 753, 7, 31, 21, 130, 198, 754], [120, 27, 16, 13, 272, 13], [4, 39, 295, 30, 382, 73, 133, 57, 39, 49, 104], [65, 35, 226, 126, 13, 30, 45, 30, 40, 299, 25, 25, 33, 3, 55, 72, 16, 40, 37], [18, 4, 100, 383, 755, 4], [31, 68, 337, 87, 9, 5, 103, 26], [16, 41], [52, 145, 457, 3, 23, 10, 11], [13, 210], [134, 369, 60, 188, 458, 543, 544, 756, 545, 546, 757, 547, 548, 758, 549], [42, 48, 289, 114, 12, 95, 211], [759, 760, 33, 210, 227, 116, 75, 761], [9, 41, 69, 40, 30, 45], [27, 39, 7, 14, 8, 31, 146, 31], [273, 7, 40, 93, 24, 40], [120, 31, 6, 32, 50], [36], [120, 550, 338, 300, 22, 167, 301], [120, 339, 77, 13, 302, 762, 19, 339, 6, 20, 155, 20, 43, 138, 13, 763, 62, 274, 339, 251, 211, 12, 50, 26, 551, 444, 77, 13, 62, 274, 189, 22, 135, 552, 764, 223, 19, 339, 14, 70, 12, 177, 6, 41, 765, 189, 163, 552, 553, 19, 340, 766, 767, 39, 340, 123, 34, 34, 199, 139, 77, 199, 139, 163, 21, 384, 459, 20, 36, 302, 156, 20, 36], [173, 27, 16, 4, 12, 128, 303, 385], [26, 32, 6], [2, 43, 768, 554, 51, 555, 444, 2, 182, 304, 2, 554, 460, 769, 54, 271, 556, 557, 556, 168, 770, 8, 38, 771, 54, 271, 288, 51, 198], [42, 22, 39, 7, 102, 273], [2, 134, 289, 149, 36, 199, 139, 558, 4, 75, 772], [24, 4, 19, 6, 83, 254, 773], [36, 20, 774, 228], [59, 12, 27 ...
# Sequências de teste: [[40, 13, 45, 21, 226, 7, 862, 13, 37], [148, 50, 270], [2, 253, 31, 7], [428, 177, 27, 16, 493, 370, 474, 12, 504], [87, 9, 5, 32, 106, 10, 11], [459, 2, 17, 32], [48, 244, 47, 14, 160, 73, 243, 47, 6, 43, 37, 183, 20, 10, 67, 30, 203, 6, 245, 14, 70, 15, 73, 133, 57, 57, 37, 6, 39, 49, 104, 240, 241], [2, 22, 129, 12, 5], [36, 46], [48, 50, 19, 6], [42, 22, 93, 701, 7, 14, 8], [22, 130, 4, 7, 14, 60, 132, 130], [289, 984, 7, 346, 171, 178, 162, 251, 169, 1], [65, 43, 20, 59, 65, 145, 14, 1053, 43, 37, 15, 4, 23, 10, 11], [42, 31, 6, 26], [2, 5, 61, 312, 231, 179, 6, 67, 192, 115, 138, 47], [2, 29, 7, 125, 3, 55, 72, 16, 316, 317, 106, 10, 11], [21, 28, 130, 60, 4, 7], [104, 43, 75, 46, 199, 139, 558, 4, 75, 683], [30, 97, 157, 248, 43, 1], [28, 46, 36, 39, 49, 4, 54, 109, 117], [67, 7, 29, 2, 441, 2, 105, 31, 60, 189, 39, 49, 104, 56, 514], [1272, 6], [148, 116, 16, 20, 31, 116], [259, 1, 33, 1223, 619, 1, 185, 949, 619, 185, 157, 298, 1, 271, 1, 1, 1, 56, 1, 355, 402, 167, 98, 41, 480, 259, 185, 171, 178, 259, 291, 171, 178, 171, 178, 213, 260, 481, 482, 171, 178, 213, 260, 403, 92, 10, 11], [4, 15, 27, 40], [48, 209, 1089, 12, 33, 247, 39, 130, 79, 4, 77, 247, 93, 809, 375, 872, 33, 1, 465, 62, 274, 10, 196, 472, 5, 223], [2, 115, 397, 3, 8, 26, 27, 230, 43, 146, 12, 645], [664, 16, 17, 4, 186, 1], [34, 235, 415, 1087, 1, 36, 65, 292, 75, 945, 63, 88, 29, 58, 44, 54, 109, 117, 75, 616], [42, 369, 24, 223, 231, 36, 341, 63, 1, 181, 20, 175, 85, 1, 197, 44, 54, 33, 77, 1072, 888, 1, 182, 1, 865, 334, 24, 31, 54], [175, 44, 54, 271, 46, 36, 319, 405, 12, 33, 210, 163, 24, 184, 12, 24, 46], [424, 211, 129, 12], [2, 28, 46, 80], [2, 18, 61], [1, 14, 22, 903, 89], [78, 122, 69, 7, 65, 40, 37, 126, 13, 30, 52, 8], [28, 97, 34, 235, 689, 1220, 10, 67, 396], [71, 49], [22, 5, 8, 156, 227, 987, 494], [49, 104, 180, 10, 61, 1266, 52, 3, 256, 155], [18, 35, 52, 23, 10, 11], [202, 20, 4, 179, 6, 10, 164, 47, 104], [18, 61, 471, 52, 1, 1, 3, 1, 155], [22, 336, 50, 6, 900, 31, 177, 32, 103, 320, 26, 6], [1, 142, 231, 24, 46, 36, 1, 18, 4, 1, 1, 46, 197, 44, 54, 271, 33, 1, 33, 1, 73, 1, 182, 71, 334, 1, 93, 1264], [18, 4, 202, 30, 47, 14, 234, 3, 138, 310, 5], [53, 132, 1, 156, 49, 1, 121, 72, 188, 108, 90, 14, 136, 3, 8, 38, 99, 43, 29, 18, 118, 91, 21, 20, 59, 15, 3, 8, 38, 21, 137, 5, 12, 126, 57, 94, 159], [148, 14, 15], [134, 214, 126, 3, 8, 55, 13, 201, 257, 60], [2, 28, 67, 1, 185, 33, 1, 3, 8, 292, 1, 185, 63, 95, 28, 4, 44, 109, 117, 85, 1076], [2, 9, 58, 6, 5, 56, 9, 9, 9, 106, 10, 11], [794, 7, 102], [42, 22, 36], [1, 182, 198], [48, 35, 4, 124, 20, 9, 5, 111], [173, 175, 19, 1, 1, 162, 33, 95, 1, 19, 297, 875, 1227, 62, 274, 1, 30, 463, 39, 1019, 1227, 62, 191, 51, 19], [4, 268, 13, 37, 6, 478, 1, 15], [1, 637, 207, 12, 1, 113], [71, 315, 24, 50, 351, 17, 50, 560, 334], [22, 103, 24, 9], [2, 27, 69, 17, 83, 35, 12, 1, 6], [95, 417, 539, 199, 371, 1, 139, 1], [2, 167, 273, 7, 14, 93, 838, 116], [83, 483, 32, 32], [2, 15, 51, 32, 92, 10, 11, 592, 155], [2, 50, 13, 8, 89, 12, 8], [55, 15, 224, 15, 4, 300, 15], [65, 20, 36, 8, 38, 63, 88, 91, 41, 151, 3, 8, 262, 94, 485, 23, 10, 11], [55, 113, 170, 34, 113, 257, 1, 1, 389, 389, 573, 92, 10, 11], [24, 4, 31, 343, 4, 17], [93, 3, 45, 25, 25, 3], [1, 20, 551, 8, 33, 168, 212, 49, 164], [189, 22, 31, 410, 20, 413, 9, 662], [2, 1, 148, 341, 20, 114, 888, 395, 511, 334, 73, 1, 1, 1, 138, 1063, 1, 1062, 43, 34, 1245], [148, 69, 24, 275, 71, 33, 865, 24, 89, 78, 196, 19, 372, 24, 8], [2, 1, 36, 46, 204, 23, 10, 11], [386, 81, 131, 18, 61, 5], [24, 50, 17, 32, 26, 103, 26], [48, 27, 14, 17, 89, 12], [189, 479, 50, 231, 135, 1, 2, 187, 551, 444, 13, 302, 187, 135, 1, 1, 13, 62, 274, 763, 177, 1048, 187, 479], [2, 5, 418, 212], [120, 1, 58, 247, 163, 196, 425], [48, 76, 484, 60, 3], [2, 5, 86, 237, 2, 56, 150, 37, 6, 23, 10, 11], [32, 9, 5, 111, 23, 10, 11], [2, 28, 114, 55, 3, 96, 9, 84, 168, 212, 67, 80, 129, 250, 13, 183, 250, 198, 30, 162, 12, 1, 49, 28, 67, 395, 1, ...

# %% [markdown]
# ## 2.5 Normalização

# %%
# Padding para garantir que todas as sequências tenham o mesmo comprimento
max_seq_length = max(len(seq) for seq in train_sequences)
train_padded = pad_sequences(train_sequences, maxlen=max_seq_length, padding='post')
test_padded = pad_sequences(test_sequences, maxlen=max_seq_length, padding='post')

# %% [markdown]
# ## 2.6 Categorizar as labels

# %%
# Codificação das labels
label_encoder = LabelEncoder()
train_labels_encoded = label_encoder.fit_transform(train_labels)
test_labels_encoded = label_encoder.transform(test_labels)

# %%
# Conversão para categórico
train_labels_categorical = to_categorical(train_labels_encoded)
test_labels_categorical = to_categorical(test_labels_encoded)

# %%
# Salvar tamanho do vocabulário
vocab_size = len(tokenizer.word_index) + 1

# %% [markdown]
# # 3. Rede Neural Classificação
#
# Nesta seção foi construída a rede neural para a classificação de intenção a partir das perguntas que foram fornecida na base de dados.

# %% [markdown]
# ## 3.1 Definição da rede neural
#
# A função create_neural_network constrói uma rede neural utilizando uma arquitetura flexível e parametrizável. O modelo começa com uma camada de embedding, responsável por converter as palavras em vetores de dimensão out_dim, sendo o tamanho máximo da sequência definido por max_seq_length e o tamanho do vocabulário por vocab_size. Após isso, a rede inclui uma camada recorrente, que pode ser configurada como LSTM, GRU ou SimpleRNN, dependendo do valor do parâmetro rnn_type, com o número de unidades dessa camada definido por units. Para lidar com o overfitting, é aplicada uma camada de dropout com a taxa definida por dropout.
#
# Caso a camada escolhida seja LSTM ou GRU, a rede usa a versão Bidirectional, que permite que o modelo aprenda relações tanto na direção da sequência quanto na inversa. No caso da RNN simples, a mesma lógica é aplicada. O modelo então adiciona duas camadas densas adicionais: a primeira com 128 neurônios e a segunda com 64 neurônios, ambas utilizando a função de ativação ReLU, seguidas por camadas de dropout para melhorar a regularização.
#
# A camada final do modelo é uma camada de saída, que possui o número de neurônios correspondente ao número de classes a serem previstas (output_classes), e utiliza a ativação softmax para produzir as probabilidades para cada classe.
#
# Por fim, o modelo é compilado utilizando o otimizador escolhido, podendo ser o Adam ou o RMSprop, com a taxa de aprendizado configurável via o parâmetro learning_rate. A função retorna o modelo pronto para o treinamento, já com a função de perda categorical_crossentropy e a métrica de desempenho accuracy configuradas.

# %%
def create_neural_network(vocab_size, max_seq_length, out_dim, output_classes, rnn_type='LSTM', units=128, dropout=0.5, optimizer='adam', learning_rate=0.001):
    """
    Cria um modelo de rede neural com base em hiperparâmetros configuráveis, incluindo duas camadas adicionais.

    Args:
        vocab_size (int): Tamanho do vocabulário.
        max_seq_length (int): Tamanho máximo da sequência.
        out_dim (int): Dimensão dos embeddings.
        output_classes (int): Número de classes de saída.
        rnn_type (str): Tipo de camada RNN, 'LSTM', 'GRU' ou 'SimpleRNN'. Default é 'LSTM'.
        units (int): Número de unidades na camada RNN. Default é 128.
        dropout (float): Taxa de dropout. Default é 0.5.
        optimizer (str): Otimizador a ser usado. Default é 'adam'.
        learning_rate (float): Taxa de aprendizado. Default é 0.001.

    Returns:
        model (Sequential): O modelo de rede neural configurado.
    """

    model = Sequential()
    # Camada de Embedding
    model.add(Embedding(input_dim=vocab_size, output_dim=out_dim, input_length=max_seq_length, trainable=True))

    # Camada RNN (LSTM, GRU ou SimpleRNN)
    if rnn_type == 'LSTM':
        model.add(Bidirectional(LSTM(units=units, return_sequences=False, dropout=dropout, recurrent_dropout=0.2)))
    elif rnn_type == 'GRU':
        model.add(Bidirectional(GRU(units=units, return_sequences=False, dropout=dropout, recurrent_dropout=0.2)))
    elif rnn_type == 'SimpleRNN':
        model.add(Bidirectional(SimpleRNN(units=units, return_sequences=False, dropout=dropout)))

    # Primeira camada densa adicional
    model.add(Dense(128, activation='relu'))
    model.add(Dropout(dropout))

    # Segunda camada densa adicional
    model.add(Dense(64, activation='relu'))
    model.add(Dropout(dropout))

    # Camada final de classificação
    model.add(Dense(output_classes, activation='softmax'))

    # Configurando otimizador
    if optimizer == 'adam':
        opt = Adam(learning_rate=learning_rate)
    elif optimizer == 'rmsprop':
        opt = RMSprop(learning_rate=learning_rate)

    model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])

    model.summary()

    return model

# %% [markdown]
# A função train_neural_network realiza o treinamento de um modelo de rede neural usando os dados de treino e validação. O treinamento é configurado com um número definido de épocas (padrão 500) e tamanho de batch (padrão 128). A função utiliza early stopping para interromper o treinamento caso o desempenho em validação não melhore por 20 épocas, e um scheduler de taxa de aprendizado para ajustá-la automaticamente. Ao final, retorna o histórico de treinamento, o tempo total gasto e o uso de memória durante o processo.

# %%
def train_neural_network(model, train_padded, train_labels_categorical, test_padded, test_labels_categorical, epochs=500, batch_size=128):
    """
    Treina o modelo de rede neural.

    Args:
        model (Sequential): Modelo criado pela função create_neural_network.
        train_padded (np.array): Dados de treinamento com padding aplicado.
        train_labels_categorical (np.array): Labels de treinamento em formato categórico.
        test_padded (np.array): Dados de validação com padding aplicado.
        test_labels_categorical (np.array): Labels de validação em formato categórico.
        epochs (int): Número de épocas para treinamento. Default é 500.
        batch_size (int): Tamanho do batch. Default é 128.

    Returns:
        history (History): Histórico de treinamento.
        elapsed_time (float): Tempo decorrido durante o treinamento.
        memory_usage (float): Uso de memória durante o treinamento em MB.
    """

    early_stopping = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)
    lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=10, verbose=1)

    start_time = time.time()
    history = model.fit(train_padded, train_labels_categorical, epochs=epochs, validation_data=(test_padded, test_labels_categorical),
                        batch_size=batch_size, callbacks=[early_stopping, lr_scheduler])
    end_time = time.time()
    elapsed_time = end_time - start_time

    process = psutil.Process()
    memory_usage = process.memory_info().rss / (1024 * 1024)  # Converter para MB

    return history, elapsed_time, memory_usage

# %% [markdown]
# ## 3.2 Treinamento da rede neural
#
# Para o treinamento da rede neural, foram utilizados os dados de treino e teste previamente pré-processados. Três diferentes arquiteturas de redes neurais recorrentes foram treinadas: SimpleRNN, GRU e LSTM, cada uma com seus próprios parâmetros e características. O treinamento foi realizado por 500 épocas e com um batch size de 128. Além disso, foi adicionado o Early Stopping, com base no desempenho em dados de validação, para evitar o problema de overfitting, interrompendo o treinamento caso a performance do modelo não melhore após um número pré-definido de épocas consecutivas.

# %%
# SimpleRNN
modelRNN = create_neural_network(vocab_size=vocab_size, max_seq_length=max_seq_length, out_dim=300, output_classes=len(label_encoder.classes_), rnn_type='SimpleRNN')

# GRU
modelGRU = create_neural_network(vocab_size=vocab_size, max_seq_length=max_seq_length, out_dim=300, output_classes=len(label_encoder.classes_), rnn_type='GRU')

# LSTM
modelLSTM = create_neural_network(vocab_size=vocab_size, max_seq_length=max_seq_length, out_dim=300, output_classes=len(label_encoder.classes_), rnn_type='LSTM')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)                │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ bidirectional (Bidirectional)        │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ ?                           │     0 (unbuilt) │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ embedding_1 (Embedding)              │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ bidirectional_1 (Bidirectional)      │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ ?                           │     0 (unbuilt) │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ embedding_2 (Embedding)              │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ bidirectional_2 (Bidirectional)      │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_6 (Dense)                      │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_4 (Dropout)                  │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_7 (Dense)                      │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_5 (Dropout)                  │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_8 (Dense)                      │ ?                           │     0 (unbuilt) │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
historyRNN, elapsed_timeRNN, memory_usageRNN = train_neural_network(
    modelRNN,
    train_padded,
    train_labels_categorical,
    test_padded,
    test_labels_categorical,
    epochs=50,
    batch_size=32
)

historyLSTM, elapsed_timeLSTM, memory_usageLSTM = train_neural_network(
    modelLSTM,
    train_padded,
    train_labels_categorical,
    test_padded,
    test_labels_categorical,
    epochs=50,
    batch_size=32
)

historyGRU, elapsed_timeGRU, memory_usageGRU = train_neural_network(
    modelGRU,
    train_padded,
    train_labels_categorical,
    test_padded,
    test_labels_categorical,
    epochs=50,
    batch_size=32
)
# Out:
# Epoch 1/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 11s 155ms/step - accuracy: 0.0677 - loss: 3.1236 - val_accuracy: 0.1810 - val_loss: 2.9400 - learning_rate: 0.0010
# Epoch 2/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 5s 172ms/step - accuracy: 0.1359 - loss: 2.9520 - val_accuracy: 0.2198 - val_loss: 2.8222 - learning_rate: 0.0010
# Epoch 3/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 6s 188ms/step - accuracy: 0.1381 - loss: 2.8056 - val_accuracy: 0.1810 - val_loss: 2.8356 - learning_rate: 0.0010
# Epoch 4/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 9s 152ms/step - accuracy: 0.1855 - loss: 2.8383 - val_accuracy: 0.1810 - val_loss: 2.7264 - learning_rate: 0.0010
# Epoch 5/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 6s 180ms/step - accuracy: 0.1590 - loss: 2.8714 - val_accuracy: 0.1853 - val_loss: 2.6662 - learning_rate: 0.0010
# Epoch 6/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 4s 128ms/step - accuracy: 0.1969 - loss: 2.7184 - val_accuracy: 0.2371 - val_loss: 2.7669 - learning_rate: 0.0010
# Epoch 7/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 4s 126ms/step - accuracy: 0.1878 - loss: 2.7920 - val_accuracy: 0.1810 - val_loss: 2.5460 - learning_rate: 0.0010
# Epoch 8/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 6s 196ms/step - accuracy: 0.2138 - loss: 2.6001 - val_accuracy: 0.2845 - val_loss: 2.4118 - learning_rate: 0.0010
# Epoch 9/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 8s 129ms/step - accuracy: 0.2570 - loss: 2.4937 - val_accuracy: 0.2974 - val_loss: 2.4095 - learning_rate: 0.0010
# Epoch 10/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 5s 166ms/step - accuracy: 0.2850 - loss: 2.3559 - val_accuracy: 0.2371 - val_loss: 2.3903 - learning_rate: 0.0010
# Epoch 11/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 5s 165ms/step - accuracy: 0.2887 - loss: 2.3210 - val_accuracy: 0.3017 - val_loss: 2.3223 - learning_rate: 0.0010
# Epoch 12/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 4s 123ms/step - accuracy: 0.2907 - loss: 2.3588 - val_accuracy: 0.3276 - val_loss: 2.2816 - learning_rate: 0.0010
# Epoch 13/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 6s 196ms/step - accuracy: 0.3437 - loss: 2.1637 - val_accuracy: 0.3362 - val_loss: 2.2249 - learning_rate: 0.0010
# Epoch 14/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 8s 126ms/step - accuracy: 0.3232 - loss: 2.1376 - val_accuracy: 0.3621 - val_loss: 2.2108 - learning_rate: 0.0010
# Epoch 15/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 6s 159ms/step - accuracy: 0.4097 - loss: 1.8840 - val_accuracy: 0.3405 - val_loss: 2.1639 - learning_rate: 0.0010
# Epoch 16/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 5s 169ms/step - accuracy: 0.4086 - loss: 1.8923 - val_accuracy: 0.3922 - val_loss: 2.1654 - learning_rate: 0.0010
# Epoch 17/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 4s 125ms/step - accuracy: 0.4090 - loss: 1.8384 - val_accuracy: 0.4009 - val_loss: 2.0808 - learning_rate: 0.0010
# Epoch 18/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 6s 140ms/step - accuracy: 0.4739 - loss: 1.6960 - val_accuracy: 0.3966 - val_loss: 2.0981 - learning_rate: 0.0010
# Epoch 19/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 6s 169ms/step - accuracy: 0.4943 - loss: 1.5895 - val_accuracy: 0.4181 - val_loss: 2.0417 - learning_rate: 0.0010
# Epoch 20/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 4s 130ms/step - accuracy: 0.5064 - loss: 1.5933 - val_accuracy: 0.4138 - val_loss: 2.0279 - learning_rate: 0.0010
# Epoch 21/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 4s 125ms/step - accuracy: 0.5446 - loss: 1.4784 - val_accuracy: 0.4138 - val_loss: 2.0504 - learning_rate: 0.0010
# Epoch 22/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 6s 208ms/step - accuracy: 0.5612 - loss: 1.4125 - val_accuracy: 0.4009 - val_loss: 2.0025 - learning_rate: 0.0010
# Epoch 23/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 8s 125ms/step - accuracy: 0.5755 - loss: 1.3498 - val_accuracy: 0.3966 - val_loss: 2.0841 - learning_rate: 0.0010
# Epoch 24/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 202ms/step - accuracy: 0.6073 - loss: 1.2247 - val_accuracy: 0.4009 - val_loss: 2.1881 - learning_rate: 0.0010
# Epoch 25/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 4s 124ms/step - accuracy: 0.6153 - loss: 1.1556 - val_accuracy: 0.4138 - val_loss: 2.1251 - learning_rate: 0.0010
# Epoch 26/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 4s 125ms/step - accuracy: 0.6889 - loss: 1.0215 - val_accuracy: 0.3879 - val_loss: 2.1632 - learning_rate: 0.0010
# Epoch 27/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 4s 141ms/step - accuracy: 0.7274 - loss: 0.9064 - val_accuracy: 0.3793 - val_loss: 2.1586 - learning_rate: 0.0010
# Epoch 28/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 6s 166ms/step - accuracy: 0.7093 - loss: 0.9220 - val_accuracy: 0.4009 - val_loss: 2.2565 - learning_rate: 0.0010
# Epoch 29/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 4s 123ms/step - accuracy: 0.7353 - loss: 0.7821 - val_accuracy: 0.3750 - val_loss: 2.4326 - learning_rate: 0.0010
# Epoch 30/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 5s 132ms/step - accuracy: 0.7446 - loss: 0.8224 - val_accuracy: 0.4009 - val_loss: 2.5995 - learning_rate: 0.0010
# Epoch 31/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 6s 202ms/step - accuracy: 0.7825 - loss: 0.7356 - val_accuracy: 0.4138 - val_loss: 2.6007 - learning_rate: 0.0010
# Epoch 32/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.7578 - loss: 0.7014
# Epoch 32: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 8s 130ms/step - accuracy: 0.7582 - loss: 0.7016 - val_accuracy: 0.3879 - val_loss: 2.6220 - learning_rate: 0.0010
# Epoch 33/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 8s 219ms/step - accuracy: 0.7555 - loss: 0.6892 - val_accuracy: 0.3836 - val_loss: 2.5591 - learning_rate: 5.0000e-04
# Epoch 34/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 122ms/step - accuracy: 0.8182 - loss: 0.5570 - val_accuracy: 0.4052 - val_loss: 2.5187 - learning_rate: 5.0000e-04
# Epoch 35/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 193ms/step - accuracy: 0.8260 - loss: 0.5392 - val_accuracy: 0.3966 - val_loss: 2.5403 - learning_rate: 5.0000e-04
# Epoch 36/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 8s 128ms/step - accuracy: 0.8351 - loss: 0.4828 - val_accuracy: 0.4095 - val_loss: 2.6028 - learning_rate: 5.0000e-04
# Epoch 37/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 211ms/step - accuracy: 0.8585 - loss: 0.4715 - val_accuracy: 0.4009 - val_loss: 2.8624 - learning_rate: 5.0000e-04
# Epoch 38/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 8s 122ms/step - accuracy: 0.8422 - loss: 0.4879 - val_accuracy: 0.4138 - val_loss: 2.8367 - learning_rate: 5.0000e-04
# Epoch 39/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 195ms/step - accuracy: 0.8665 - loss: 0.4141 - val_accuracy: 0.4310 - val_loss: 2.7589 - learning_rate: 5.0000e-04
# Epoch 40/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.8714 - loss: 0.4281 - val_accuracy: 0.4310 - val_loss: 2.6517 - learning_rate: 5.0000e-04
# Epoch 41/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 5s 165ms/step - accuracy: 0.8391 - loss: 0.4614 - val_accuracy: 0.4138 - val_loss: 2.9117 - learning_rate: 5.0000e-04
# Epoch 42/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.8630 - loss: 0.4085
# Epoch 42: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 5s 171ms/step - accuracy: 0.8632 - loss: 0.4086 - val_accuracy: 0.4181 - val_loss: 2.8397 - learning_rate: 5.0000e-04
# Epoch 1/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 25s 688ms/step - accuracy: 0.0658 - loss: 3.0616 - val_accuracy: 0.1810 - val_loss: 2.8736 - learning_rate: 0.0010
# Epoch 2/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 24s 824ms/step - accuracy: 0.1523 - loss: 2.8729 - val_accuracy: 0.1853 - val_loss: 2.7009 - learning_rate: 0.0010
# Epoch 3/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 38s 718ms/step - accuracy: 0.2217 - loss: 2.7012 - val_accuracy: 0.2328 - val_loss: 2.4978 - learning_rate: 0.0010
# Epoch 4/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 37s 578ms/step - accuracy: 0.2181 - loss: 2.5500 - val_accuracy: 0.2759 - val_loss: 2.4268 - learning_rate: 0.0010
# Epoch 5/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 20s 574ms/step - accuracy: 0.2775 - loss: 2.3753 - val_accuracy: 0.2759 - val_loss: 2.3297 - learning_rate: 0.0010
# Epoch 6/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 21s 576ms/step - accuracy: 0.2932 - loss: 2.2899 - val_accuracy: 0.3276 - val_loss: 2.2351 - learning_rate: 0.0010
# Epoch 7/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 20s 571ms/step - accuracy: 0.3174 - loss: 2.2320 - val_accuracy: 0.3879 - val_loss: 2.1065 - learning_rate: 0.0010
# Epoch 8/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 17s 585ms/step - accuracy: 0.4133 - loss: 1.9705 - val_accuracy: 0.4397 - val_loss: 1.9961 - learning_rate: 0.0010
# Epoch 9/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 20s 569ms/step - accuracy: 0.4696 - loss: 1.7648 - val_accuracy: 0.4353 - val_loss: 2.0025 - learning_rate: 0.0010
# Epoch 10/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 22s 620ms/step - accuracy: 0.4627 - loss: 1.6554 - val_accuracy: 0.4612 - val_loss: 1.9664 - learning_rate: 0.0010
# Epoch 11/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 20s 682ms/step - accuracy: 0.5134 - loss: 1.5576 - val_accuracy: 0.4569 - val_loss: 1.9236 - learning_rate: 0.0010
# Epoch 12/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 19s 674ms/step - accuracy: 0.5329 - loss: 1.4160 - val_accuracy: 0.4612 - val_loss: 2.0056 - learning_rate: 0.0010
# Epoch 13/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 17s 579ms/step - accuracy: 0.5743 - loss: 1.3061 - val_accuracy: 0.4569 - val_loss: 1.9705 - learning_rate: 0.0010
# Epoch 14/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 22s 614ms/step - accuracy: 0.5899 - loss: 1.2074 - val_accuracy: 0.4784 - val_loss: 2.0922 - learning_rate: 0.0010
# Epoch 15/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 19s 591ms/step - accuracy: 0.6371 - loss: 1.1661 - val_accuracy: 0.4655 - val_loss: 2.0578 - learning_rate: 0.0010
# Epoch 16/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 18s 620ms/step - accuracy: 0.6183 - loss: 1.1779 - val_accuracy: 0.4784 - val_loss: 2.2311 - learning_rate: 0.0010
# Epoch 17/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 20s 611ms/step - accuracy: 0.6479 - loss: 1.0340 - val_accuracy: 0.4784 - val_loss: 2.1186 - learning_rate: 0.0010
# Epoch 18/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 21s 603ms/step - accuracy: 0.6490 - loss: 1.0584 - val_accuracy: 0.4698 - val_loss: 2.2856 - learning_rate: 0.0010
# Epoch 19/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 20s 609ms/step - accuracy: 0.6734 - loss: 0.9893 - val_accuracy: 0.4569 - val_loss: 2.2421 - learning_rate: 0.0010
# Epoch 20/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 17s 590ms/step - accuracy: 0.6866 - loss: 0.8807 - val_accuracy: 0.4655 - val_loss: 2.2967 - learning_rate: 0.0010
# Epoch 21/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 560ms/step - accuracy: 0.7207 - loss: 0.8061
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 17s 589ms/step - accuracy: 0.7202 - loss: 0.8082 - val_accuracy: 0.4612 - val_loss: 2.4409 - learning_rate: 0.0010
# Epoch 22/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 22s 648ms/step - accuracy: 0.7001 - loss: 0.8447 - val_accuracy: 0.4655 - val_loss: 2.4473 - learning_rate: 5.0000e-04
# Epoch 23/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 20s 684ms/step - accuracy: 0.7291 - loss: 0.8025 - val_accuracy: 0.4741 - val_loss: 2.4047 - learning_rate: 5.0000e-04
# Epoch 24/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 20s 680ms/step - accuracy: 0.7635 - loss: 0.7097 - val_accuracy: 0.4741 - val_loss: 2.5659 - learning_rate: 5.0000e-04
# Epoch 25/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 29s 991ms/step - accuracy: 0.7730 - loss: 0.6127 - val_accuracy: 0.4871 - val_loss: 2.5963 - learning_rate: 5.0000e-04
# Epoch 26/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 30s 1s/step - accuracy: 0.7688 - loss: 0.7184 - val_accuracy: 0.4698 - val_loss: 2.6096 - learning_rate: 5.0000e-04
# Epoch 27/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 30s 633ms/step - accuracy: 0.7588 - loss: 0.7041 - val_accuracy: 0.4957 - val_loss: 2.6410 - learning_rate: 5.0000e-04
# Epoch 28/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 19s 590ms/step - accuracy: 0.7785 - loss: 0.6464 - val_accuracy: 0.4914 - val_loss: 2.7245 - learning_rate: 5.0000e-04
# Epoch 29/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 17s 605ms/step - accuracy: 0.7822 - loss: 0.6356 - val_accuracy: 0.4698 - val_loss: 2.8949 - learning_rate: 5.0000e-04
# Epoch 30/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 22s 671ms/step - accuracy: 0.7551 - loss: 0.6550 - val_accuracy: 0.4655 - val_loss: 2.8398 - learning_rate: 5.0000e-04
# Epoch 31/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 781ms/step - accuracy: 0.8028 - loss: 0.5845
# Epoch 31: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 29s 965ms/step - accuracy: 0.8024 - loss: 0.5846 - val_accuracy: 0.4655 - val_loss: 2.7306 - learning_rate: 5.0000e-04
# Epoch 1/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 30s 759ms/step - accuracy: 0.1013 - loss: 3.0543 - val_accuracy: 0.1810 - val_loss: 2.9085 - learning_rate: 0.0010
# Epoch 2/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 20s 712ms/step - accuracy: 0.1536 - loss: 2.8422 - val_accuracy: 0.1810 - val_loss: 2.8343 - learning_rate: 0.0010
# Epoch 3/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 18s 615ms/step - accuracy: 0.2095 - loss: 2.6894 - val_accuracy: 0.2026 - val_loss: 2.5266 - learning_rate: 0.0010
# Epoch 4/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 20s 602ms/step - accuracy: 0.2535 - loss: 2.4775 - val_accuracy: 0.2802 - val_loss: 2.4250 - learning_rate: 0.0010
# Epoch 5/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 21s 614ms/step - accuracy: 0.3293 - loss: 387.5424 - val_accuracy: 0.3103 - val_loss: 2.3576 - learning_rate: 0.0010
# Epoch 6/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 19s 579ms/step - accuracy: 0.3334 - loss: 2.2028 - val_accuracy: 0.3448 - val_loss: 2.2493 - learning_rate: 0.0010
# Epoch 7/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 21s 597ms/step - accuracy: 0.3629 - loss: 2.1574 - val_accuracy: 0.3578 - val_loss: 2.2027 - learning_rate: 0.0010
# Epoch 8/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 23s 673ms/step - accuracy: 0.4190 - loss: 1.8884 - val_accuracy: 0.3707 - val_loss: 2.1126 - learning_rate: 0.0010
# Epoch 9/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 17s 598ms/step - accuracy: 0.4307 - loss: 1.8088 - val_accuracy: 0.3922 - val_loss: 2.0396 - learning_rate: 0.0010
# Epoch 10/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 20s 589ms/step - accuracy: 0.4592 - loss: 1.6596 - val_accuracy: 0.4095 - val_loss: 2.0162 - learning_rate: 0.0010
# Epoch 11/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 20s 591ms/step - accuracy: 0.5164 - loss: 1.5066 - val_accuracy: 0.4095 - val_loss: 2.0278 - learning_rate: 0.0010
# Epoch 12/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 24s 711ms/step - accuracy: 0.4877 - loss: 1.5939 - val_accuracy: 0.4095 - val_loss: 2.0122 - learning_rate: 0.0010
# Epoch 13/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 38s 612ms/step - accuracy: 0.5430 - loss: 1.4188 - val_accuracy: 0.4267 - val_loss: 2.0272 - learning_rate: 0.0010
# Epoch 14/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 20s 604ms/step - accuracy: 0.5901 - loss: 1.3111 - val_accuracy: 0.4267 - val_loss: 2.0340 - learning_rate: 0.0010
# Epoch 15/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 17s 597ms/step - accuracy: 0.5565 - loss: 1.2472 - val_accuracy: 0.4612 - val_loss: 2.0253 - learning_rate: 0.0010
# Epoch 16/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 18s 638ms/step - accuracy: 0.6073 - loss: 1.2129 - val_accuracy: 0.4310 - val_loss: 2.0657 - learning_rate: 0.0010
# Epoch 17/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 19s 592ms/step - accuracy: 0.6216 - loss: 1.1071 - val_accuracy: 0.4181 - val_loss: 2.0728 - learning_rate: 0.0010
# Epoch 18/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 20s 587ms/step - accuracy: 0.6262 - loss: 1.1215 - val_accuracy: 0.4526 - val_loss: 2.0657 - learning_rate: 0.0010
# Epoch 19/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 20s 564ms/step - accuracy: 0.6477 - loss: 4306.8223 - val_accuracy: 0.4095 - val_loss: 2.1801 - learning_rate: 0.0010
# Epoch 20/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 16s 559ms/step - accuracy: 0.6470 - loss: 1.0918 - val_accuracy: 0.4224 - val_loss: 2.2080 - learning_rate: 0.0010
# Epoch 21/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 16s 569ms/step - accuracy: 0.6467 - loss: 1.0684 - val_accuracy: 0.4267 - val_loss: 2.1541 - learning_rate: 0.0010
# Epoch 22/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 542ms/step - accuracy: 0.6453 - loss: 1.0113
# Epoch 22: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 16s 568ms/step - accuracy: 0.6457 - loss: 1.0107 - val_accuracy: 0.4440 - val_loss: 2.1545 - learning_rate: 0.0010
# Epoch 23/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 22s 613ms/step - accuracy: 0.6926 - loss: 0.9770 - val_accuracy: 0.4267 - val_loss: 2.1468 - learning_rate: 5.0000e-04
# Epoch 24/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 21s 663ms/step - accuracy: 0.6872 - loss: 0.8968 - val_accuracy: 0.4353 - val_loss: 2.1821 - learning_rate: 5.0000e-04
# Epoch 25/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 20s 648ms/step - accuracy: 0.6934 - loss: 0.8396 - val_accuracy: 0.4224 - val_loss: 2.1919 - learning_rate: 5.0000e-04
# Epoch 26/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 18s 560ms/step - accuracy: 0.6896 - loss: 0.8818 - val_accuracy: 0.4181 - val_loss: 2.2164 - learning_rate: 5.0000e-04
# Epoch 27/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 22s 604ms/step - accuracy: 0.7225 - loss: 0.8737 - val_accuracy: 0.4138 - val_loss: 2.2315 - learning_rate: 5.0000e-04
# Epoch 28/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 22s 767ms/step - accuracy: 0.7490 - loss: 0.8003 - val_accuracy: 0.4397 - val_loss: 2.2455 - learning_rate: 5.0000e-04
# Epoch 29/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 35s 572ms/step - accuracy: 0.7437 - loss: 67.1855 - val_accuracy: 0.4353 - val_loss: 2.2336 - learning_rate: 5.0000e-04
# Epoch 30/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 20s 565ms/step - accuracy: 0.7374 - loss: 0.7733 - val_accuracy: 0.4310 - val_loss: 2.2282 - learning_rate: 5.0000e-04
# Epoch 31/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 17s 576ms/step - accuracy: 0.7262 - loss: 0.8047 - val_accuracy: 0.4440 - val_loss: 2.2123 - learning_rate: 5.0000e-04
# Epoch 32/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 545ms/step - accuracy: 0.7387 - loss: 0.7872
# Epoch 32: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 21s 592ms/step - accuracy: 0.7391 - loss: 0.7864 - val_accuracy: 0.4483 - val_loss: 2.2424 - learning_rate: 5.0000e-04

# %% [markdown]
# # 4. Resultados
#
# Para avaliação do modelo enquanto ele treina foi utilizado a acurácia, pois ela define quanto que o modelo está acertando do total, sendo a mais útil para o atual modelo. Também foi acrescentado outras métricas como Recall, Precision e F1-Score.
#
# **Explicação de cada métrica:**
#
# - Acurácia: Fornece uma visão geral da performance do modelo, indicando o quão bem ele está acertando as previsões em geral.
#
# - Recall: Foca em quantos dos verdadeiros positivos foram identificados, importante quando é crucial capturar todos os casos positivos.
#
# - Precision: Avalia a qualidade das previsões positivas feitas pelo modelo, relevante quando é necessário evitar falsos positivos.
#
# - F1-Score: Oferece uma métrica balanceada que considera tanto a precisão quanto o recall, útil para cenários onde ambos os aspectos são importantes.

# %% [markdown]
# ## 4.1 Avaliação do modelo

# %% [markdown]
# ### 4.1.1 RNN

# %% [markdown]
# **Resumo RNN:**
#
# Acurácia: 40%
#
# Precisão: 34%
#
# Recall: 40%
#
# F1-Score: 35%

# %%
# Avaliação do modelo RNN
lossRNN, accuracyRNN = modelRNN.evaluate(test_padded, test_labels_categorical)
print(f'RNN - Test Accuracy: {accuracyRNN:.2f}')
print(f'RNN - Loss: {lossRNN:.2f}')

# Previsões
predictionsRNN = modelRNN.predict(test_padded)
pred_labelsRNN = predictionsRNN.argmax(axis=1)
true_labelsRNN = test_labels_categorical.argmax(axis=1)

# Cálculo das métricas
precisionRNN = precision_score(true_labelsRNN, pred_labelsRNN, average='weighted')
recallRNN = recall_score(true_labelsRNN, pred_labelsRNN, average='weighted')
f1RNN = f1_score(true_labelsRNN, pred_labelsRNN, average='weighted')

print('\nRNN - Métricas')
print(f'Precision: {precisionRNN:.2f}')
print(f'Recall: {recallRNN:.2f}')
print(f'F1-Score: {f1RNN:.2f}')
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.4015 - loss: 2.0509
# RNN - Test Accuracy: 0.40
# RNN - Loss: 2.00
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step
#
# RNN - Métricas
# Precision: 0.34
# Recall: 0.40
# F1-Score: 0.35
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# #### 4.1.1.1 Acompanhamento por época
#
# A partir desse gráfico percebe-se que o modelo está tendo um Overfitting, pois a validação fica muito abaixo do conjunto de treino, isso mostra que mesmo com o modelo com 80% de acurácia nas últimas épocas, quando há inserção de dados desconhecidos o modelo não reconhece

# %%
# Gráfico de Acurácia
plt.figure(figsize=(16, 10))

plt.subplot(2, 2, 1)
plt.plot(historyRNN.history['accuracy'], label='Train Accuracy', color='blue')
plt.plot(historyRNN.history['val_accuracy'], label='Validation Accuracy', color='cyan', linestyle='--')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('RNN - Accuracy Over Epochs')
plt.legend()

# Gráfico de Perda
plt.subplot(2, 2, 2)
plt.plot(historyRNN.history['loss'], label='Train Loss', color='red')
plt.plot(historyRNN.history['val_loss'], label='Validation Loss', color='orange', linestyle='--')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('RNN - Loss Over Epochs')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# #### 4.1.1.2 Comparação Métricas

# %%
# Gráfico de Barras para as Métricas - RNN
metricsRNN = {'Precision': precisionRNN, 'Recall': recallRNN, 'F1-Score': f1RNN}
plt.figure(figsize=(8, 6))
plt.bar(metricsRNN.keys(), metricsRNN.values(), color=['blue', 'green', 'red'])
plt.ylim(0, 1)
plt.title('RNN - Precision, Recall, and F1-Score')
plt.xlabel('Metrics')
plt.ylabel('Score')
plt.show()

# %% [markdown]
# #### 4.1.1.3 Matriz de confusão
#
# A matriz de confusão serve para validação de como o modelo está identificando as classes, percebe-se que o modelo está concentrando apenas em duas classes, evidenciando a falta de generalização das classes

# %%
# Matriz de Confusão - RNN
conf_matrixRNN = confusion_matrix(true_labelsRNN, pred_labelsRNN)

# Mapeamento de índices para rótulos
label_mapping = dict(enumerate(label_encoder.classes_))
labels = list(label_mapping.values())

# Visualize a matriz de confusão com rótulos de classes
plt.figure(figsize=(10, 8))
sns.heatmap(conf_matrixRNN, annot=True, fmt='d', cmap='Blues', cbar=False, xticklabels=labels, yticklabels=labels)
plt.title('Confusion Matrix RNN')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.savefig('confusion_matrix_RNN.png', dpi=300, bbox_inches='tight')  # Ajuste a resolução e a margem
plt.show()

# %% [markdown]
# ### 4.1.2 LSTM

# %% [markdown]
# **Resumo LSTM:**
#
# Acurácia: 46%
#
# Precisão: 37%
#
# Recall: 46%
#
# F1-Score: 39%

# %%
# Avaliação do modelo LSTM
lossLSTM, accuracyLSTM = modelLSTM.evaluate(test_padded, test_labels_categorical)
print(f'LSTM - Test Accuracy: {accuracyLSTM:.2f}')
print(f'LSTM - Loss: {lossLSTM:.2f}')

# Previsões
predictionsLSTM = modelLSTM.predict(test_padded)
pred_labelsLSTM = predictionsLSTM.argmax(axis=1)
true_labelsLSTM = test_labels_categorical.argmax(axis=1)

# Cálculo das métricas
precisionLSTM = precision_score(true_labelsLSTM, pred_labelsLSTM, average='weighted')
recallLSTM = recall_score(true_labelsLSTM, pred_labelsLSTM, average='weighted')
f1LSTM = f1_score(true_labelsLSTM, pred_labelsLSTM, average='weighted')

print('\nLSTM - Métricas')
print(f'Precision: {precisionLSTM:.2f}')
print(f'Recall: {recallLSTM:.2f}')
print(f'F1-Score: {f1LSTM:.2f}')
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - accuracy: 0.4535 - loss: 1.9032
# LSTM - Test Accuracy: 0.46
# LSTM - Loss: 1.92
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step
#
# LSTM - Métricas
# Precision: 0.37
# Recall: 0.46
# F1-Score: 0.39
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# #### 4.1.2.1 Acompanhamento por época
#
# A partir desse gráfico percebe-se que o modelo está tendo um Overfitting, pois a validação fica muito abaixo do conjunto de treino, isso mostra que mesmo com o modelo com 80% de acurácia nas últimas épocas, quando há inserção de dados desconhecidos o modelo não reconhece.

# %%
# Gráficos de Acurácia e Perda - LSTM
plt.figure(figsize=(16, 10))

# Gráfico de Acurácia
plt.subplot(2, 2, 1)
plt.plot(historyLSTM.history['accuracy'], label='Train Accuracy', color='blue')
plt.plot(historyLSTM.history['val_accuracy'], label='Validation Accuracy', color='cyan', linestyle='--')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('LSTM - Accuracy Over Epochs')
plt.legend()

# Gráfico de Perda
plt.subplot(2, 2, 2)
plt.plot(historyLSTM.history['loss'], label='Train Loss', color='red')
plt.plot(historyLSTM.history['val_loss'], label='Validation Loss', color='orange', linestyle='--')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('LSTM - Loss Over Epochs')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# #### 4.1.2.2 Comparação Métricas

# %%
# Gráfico de Barras para as Métricas - LSTM
metricsLSTM = {'Precision': precisionLSTM, 'Recall': recallLSTM, 'F1-Score': f1LSTM}
plt.figure(figsize=(8, 6))
plt.bar(metricsLSTM.keys(), metricsLSTM.values(), color=['blue', 'green', 'red'])
plt.ylim(0, 1)
plt.title('LSTM - Precision, Recall, and F1-Score')
plt.xlabel('Metrics')
plt.ylabel('Score')
plt.show()

# %% [markdown]
# #### 4.1.2.3 Matriz de confusão
#
# A matriz de confusão serve para validação de como o modelo está identificando as classes, percebe-se que o modelo está concentrando apenas em duas classes, evidenciando a falta de generalização das classes. Diferente do modelo de RNN, este modelo tem uma tendência nova que é "Problemas/Duvidas de atualizacao de dados cadastrais", mostrando ser um modelo superior, entretanto a qualidade dos dados inseridos não.

# %%
# Matriz de Confusão - LSTM
conf_matrixLSTM = confusion_matrix(true_labelsLSTM, pred_labelsLSTM)

# Mapeamento de índices para rótulos
label_mapping = dict(enumerate(label_encoder.classes_))
labels = list(label_mapping.values())

# Visualize a matriz de confusão com rótulos de classes
plt.figure(figsize=(10, 8))
sns.heatmap(conf_matrixLSTM, annot=True, fmt='d', cmap='Blues', cbar=False, xticklabels=labels, yticklabels=labels)
plt.title('Confusion Matrix LSTM')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.savefig('confusion_matrix_LSTM.png', dpi=300, bbox_inches='tight')  # Ajuste a resolução e a margem
plt.show()

# %% [markdown]
# ### 4.1.3 GRU

# %% [markdown]
# **Resumo GRU:**
#
# Acurácia: 41%
#
# Precisão: 29%
#
# Recall: 41%
#
# F1-Score: 34%

# %%
# Avaliação do modelo GRU
lossGRU, accuracyGRU = modelGRU.evaluate(test_padded, test_labels_categorical)
print(f'GRU - Test Accuracy: {accuracyGRU:.2f}')
print(f'GRU - Loss: {lossGRU:.2f}')

# Previsões
predictionsGRU = modelGRU.predict(test_padded)
pred_labelsGRU = predictionsGRU.argmax(axis=1)
true_labelsGRU = test_labels_categorical.argmax(axis=1)

# Cálculo das métricas
precisionGRU = precision_score(true_labelsGRU, pred_labelsGRU, average='weighted')
recallGRU = recall_score(true_labelsGRU, pred_labelsGRU, average='weighted')
f1GRU = f1_score(true_labelsGRU, pred_labelsGRU, average='weighted')

print('\nGRU - Métricas')
print(f'Precision: {precisionGRU:.2f}')
print(f'Recall: {recallGRU:.2f}')
print(f'F1-Score: {f1GRU:.2f}')
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 94ms/step - accuracy: 0.3897 - loss: 2.0610
# GRU - Test Accuracy: 0.41
# GRU - Loss: 2.01
# WARNING:tensorflow:5 out of the last 17 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7ef5d806c1f0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 267ms/step
#
# GRU - Métricas
# Precision: 0.29
# Recall: 0.41
# F1-Score: 0.34
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# #### 4.1.3.1 Acompanhamento por época
#
# No gráfico abaixo, percebe-se que o modelo também está com overfitting, entretanto por causa da otimização de parâmetro de reduzir o learning rate afim de encontrar um valor ótimo, entretanto reduziu tanto que acabou afetando na Loss do modelo ficando extremamente elevado, mostrando um underfitting, o modelo não está aprendendo.

# %%
# Gráficos de Acurácia e Perda - GRU
plt.figure(figsize=(16, 10))

# Gráfico de Acurácia
plt.subplot(2, 2, 1)
plt.plot(historyGRU.history['accuracy'], label='Train Accuracy', color='blue')
plt.plot(historyGRU.history['val_accuracy'], label='Validation Accuracy', color='cyan', linestyle='--')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('GRU - Accuracy Over Epochs')
plt.legend()

# Gráfico de Perda
plt.subplot(2, 2, 2)
plt.plot(historyGRU.history['loss'], label='Train Loss', color='red')
plt.plot(historyGRU.history['val_loss'], label='Validation Loss', color='orange', linestyle='--')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('GRU - Loss Over Epochs')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# #### 4.1.3.2 Comparação Métricas

# %%
# Gráfico de Barras para as Métricas - GRU
metricsGRU = {'Precision': precisionGRU, 'Recall': recallGRU, 'F1-Score': f1GRU}
plt.figure(figsize=(8, 6))
plt.bar(metricsGRU.keys(), metricsGRU.values(), color=['blue', 'green', 'red'])
plt.ylim(0, 1)
plt.title('GRU - Precision, Recall, and F1-Score')
plt.xlabel('Metrics')
plt.ylabel('Score')
plt.show()

# %% [markdown]
# #### 4.1.3.3 Comparação Métricas
#
# Assim como os outros modelos, ele tende para duas classes, logo, a comparação dos 3 modelos evidencia como o tratamento dos dados deve ser melhorado, pois foi utilizado 3 redes com estruturas diferentes e elas geraram os mesmos resultados.

# %%
# Matriz de Confusão - GRU
conf_matrixGRU = confusion_matrix(true_labelsGRU, pred_labelsGRU)

# Mapeamento de índices para rótulos
label_mapping = dict(enumerate(label_encoder.classes_))
labels = list(label_mapping.values())

# Visualize a matriz de confusão com rótulos de classes
plt.figure(figsize=(10, 8))
sns.heatmap(conf_matrixGRU, annot=True, fmt='d', cmap='Blues', cbar=False, xticklabels=labels, yticklabels=labels)
plt.title('Confusion Matrix GRU')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.savefig('confusion_matrix_GRU.png', dpi=300, bbox_inches='tight')  # Ajuste a resolução e a margem
plt.show()

# %% [markdown]
# # 5. Performance
#
# A CPU utiliza menos memória enquanto a GPU é muito mais rápida. Para fazer o treinamento com os ambos, pode ser utilizado o Google Colaboratory, na qual tem a função de trocar o ambiente de execução no campo superior direito da interface e selecionar a opção "Alterar o tipo de ambiente de execução"

# %% [markdown]
# ## 5.1 CPU

# %%
# Salvando o tempo de processamento e a memória utilizada - RNN
metrics_infoRNN = {
    "elapsed_time": elapsed_timeRNN,
    "memory_usage": memory_usageRNN
}

print(f"RNN - Elapsed Time: {elapsed_timeRNN:.2f} seconds")
print(f"RNN - Memory Usage: {memory_usageRNN:.2f} MB")

# Salvando o tempo de processamento e a memória utilizada - LSTM
metrics_infoLSTM = {
    "elapsed_time": elapsed_timeLSTM,
    "memory_usage": memory_usageLSTM
}

print(f"LSTM - Elapsed Time: {elapsed_timeLSTM:.2f} seconds")
print(f"LSTM - Memory Usage: {memory_usageLSTM:.2f} MB")

# Salvando o tempo de processamento e a memória utilizada - GRU
metrics_infoGRU = {
    "elapsed_time": elapsed_timeGRU,
    "memory_usage": memory_usageGRU
}

print(f"GRU - Elapsed Time: {elapsed_timeGRU:.2f} seconds")
print(f"GRU - Memory Usage: {memory_usageGRU:.2f} MB")
# Out:
# RNN - Elapsed Time: 253.01 seconds
# RNN - Memory Usage: 834.47 MB
# LSTM - Elapsed Time: 693.01 seconds
# LSTM - Memory Usage: 938.43 MB
# GRU - Elapsed Time: 676.03 seconds
# GRU - Memory Usage: 1037.48 MB

# %% [markdown]
# ## 5.2 GPU

# %%
# Salvando o tempo de processamento e a memória utilizada - RNN
metrics_infoRNN = {
    "elapsed_time": elapsed_timeRNN,
    "memory_usage": memory_usageRNN
}

print(f"RNN - Elapsed Time: {elapsed_timeRNN:.2f} seconds")
print(f"RNN - Memory Usage: {memory_usageRNN:.2f} MB")

# Salvando o tempo de processamento e a memória utilizada - LSTM
metrics_infoLSTM = {
    "elapsed_time": elapsed_timeLSTM,
    "memory_usage": memory_usageLSTM
}

print(f"LSTM - Elapsed Time: {elapsed_timeLSTM:.2f} seconds")
print(f"LSTM - Memory Usage: {memory_usageLSTM:.2f} MB")

# Salvando o tempo de processamento e a memória utilizada - GRU
metrics_infoGRU = {
    "elapsed_time": elapsed_timeGRU,
    "memory_usage": memory_usageGRU
}

print(f"GRU - Elapsed Time: {elapsed_timeGRU:.2f} seconds")
print(f"GRU - Memory Usage: {memory_usageGRU:.2f} MB")
# Out:
# RNN - Elapsed Time: 60.26 seconds
# RNN - Memory Usage: 1210.19 MB
# LSTM - Elapsed Time: 439.54 seconds
# LSTM - Memory Usage: 1429.45 MB
# GRU - Elapsed Time: 657.64 seconds
# GRU - Memory Usage: 1526.52 MB

# %% [markdown]
# # 6. Predições

# %% [markdown]
# Nesta seção será realizada as predições de frases que foram separadas pelo modelo, percebe-se que o modelo apresenta inconsistência tendo uma tendência para classificar como "Pedido de envio via metodo "ByPhone"". Isso ocorre porque as classes estão desbalanceadas, tendo maior quantidade de "Pedido de envio via metodo ByPhone".

# %%
# 1. Definir os textos a serem classificados
new_texts = [
    "Quando minha remessa será entregue?",  # Exemplo de intenção relacionada a "Tempo de remessa"
    "Como faço para fazer um depósito?",   # Exemplo de intenção relacionada a "Como depositar"
    "Qual o prazo de entrega?",  # Outro exemplo de "Tempo de remessa"
    "Quais são os métodos de depósito aceitos?"  # Outro exemplo de "Como depositar"
]

# 2. Tokenizar e padronizar os novos textos
# Usar o mesmo tokenizador e o parâmetro `max_len` que foi utilizado no treinamento
new_sequences = tokenizer.texts_to_sequences(new_texts)
new_padded = pad_sequences(new_sequences, maxlen=max_seq_length, padding='post')

# 3. Prever as intenções usando cada um dos modelos

# Previsão usando o modelo RNN
predictionsRNN = modelRNN.predict(new_padded)
pred_labelsRNN = predictionsRNN.argmax(axis=1)

# Previsão usando o modelo LSTM
predictionsLSTM = modelLSTM.predict(new_padded)
pred_labelsLSTM = predictionsLSTM.argmax(axis=1)

# Previsão usando o modelo GRU
predictionsGRU = modelGRU.predict(new_padded)
pred_labelsGRU = predictionsGRU.argmax(axis=1)

# 4. Mapear os índices de previsão para as intenções
label_mapping = dict(enumerate(label_encoder.classes_))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step

# %% [markdown]
# ## 6.1 RNN

# %%
# Exibir as previsões para cada modelo
print("Previsões RNN:")
for i, text in enumerate(new_texts):
    print(f"Texto: {text}")
    print(f"Intenção prevista: {label_mapping[pred_labelsRNN[i]]}\n")
# Out:
# Previsões RNN:
# Texto: Quando minha remessa será entregue?
# Intenção prevista: Pedido de envio via metodo "ByPhone"
#
# Texto: Como faço para fazer um depósito?
# Intenção prevista: Pedido de envio via metodo "ByPhone"
#
# Texto: Qual o prazo de entrega?
# Intenção prevista: Problemas/Duvidas sobre deposito
#
# Texto: Quais são os métodos de depósito aceitos?
# Intenção prevista: Pedido de envio via metodo "ByPhone"

# %% [markdown]
# ## 6.2 LSTM

# %%
print("Previsões LSTM:")
for i, text in enumerate(new_texts):
    print(f"Texto: {text}")
    print(f"Intenção prevista: {label_mapping[pred_labelsLSTM[i]]}\n")
# Out:
# Previsões LSTM:
# Texto: Quando minha remessa será entregue?
# Intenção prevista: Pedido de envio via metodo "ByPhone"
#
# Texto: Como faço para fazer um depósito?
# Intenção prevista: Termos e condicoes do servico
#
# Texto: Qual o prazo de entrega?
# Intenção prevista: Pedido de envio via metodo "ByPhone"
#
# Texto: Quais são os métodos de depósito aceitos?
# Intenção prevista: Pedido de envio via metodo "ByPhone"

# %% [markdown]
# ## 6.3 GRU

# %%
print("Previsões GRU:")
for i, text in enumerate(new_texts):
    print(f"Texto: {text}")
    print(f"Intenção prevista: {label_mapping[pred_labelsGRU[i]]}\n")
# Out:
# Previsões GRU:
# Texto: Quando minha remessa será entregue?
# Intenção prevista: Pedido de envio via metodo "ByPhone"
#
# Texto: Como faço para fazer um depósito?
# Intenção prevista: Problemas/Duvidas de atualizacao de dados cadastrais
#
# Texto: Qual o prazo de entrega?
# Intenção prevista: Tempo de remessa
#
# Texto: Quais são os métodos de depósito aceitos?
# Intenção prevista: Pedido de envio via metodo "ByPhone"
